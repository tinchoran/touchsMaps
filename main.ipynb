# %%
# %%
import pandas as pd
from statsbombpy import sb
import matplotlib.pyplot as plt
from mplsoccer import VerticalPitch, Pitch

partido = sb.events(match_id=3869685)

messi = partido[partido["player"] == "Lionel Andrés Messi Cuccittini"]
messi[["x","y"]] = messi["location"].apply(pd.Series)
messi[["x", "y", "location"]]

fig, ax = plt.subplots(figsize=(16,9))
pitch = Pitch(
    pitch_color='grass', 
    line_color='white', 
    pitch_type="statsbomb",
)

pitch.draw(ax = ax)

pitch.scatter(messi["x"], messi["y"], ax = ax, c='#f7f7f7', edgecolor="#6b0002")
# Out:
# c:\Users\xx\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# C:\Users\xx\AppData\Local\Temp\ipykernel_12972\196927371.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   messi[["x","y"]] = messi["location"].apply(pd.Series)
# C:\Users\xx\AppData\Local\Temp\ipykernel_12972\196927371.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   messi[["x","y"]] = messi["location"].apply(pd.Series)
